# %%
import numpy as np
import pandas as pd
import re

# %%
df=pd.read_csv('bbc_news.csv')

# %%
#----------------data understanding----------------

# %%
df.head()
# Out:
#                                                title  \
# 0  Ukraine: Angry Zelensky vows to punish Russian...
# 1  War in Ukraine: Taking cover in a town under a...
# 2         Ukraine war 'catastrophic for global food'
# 3  Manchester Arena bombing: Saffie Roussos's par...
# 4  Ukraine conflict: Oil price soars to highest l...
#
#                          pubDate  \
# 0  Mon, 07 Mar 2022 08:01:56 GMT
# 1  Sun, 06 Mar 2022 22:49:58 GMT
# 2  Mon, 07 Mar 2022 00:14:42 GMT
# 3  Mon, 07 Mar 2022 00:05:40 GMT
# 4  Mon, 07 Mar 2022 08:15:53 GMT
#
#                                                guid  \
# 0  https://www.bbc.co.uk/news/world-europe-60638042
# 1  https://www.bbc.co.uk/news/world-europe-60641873
# 2      https://www.bbc.co.uk/news/business-60623941
# 3            https://www.bbc.co.uk/news/uk-60579079
# 4      https://www.bbc.co.uk/news/business-60642786
#
#                                                 link  \
# 0  https://www.bbc.co.uk/news/world-europe-606380...
# 1  https://www.bbc.co.uk/news/world-europe-606418...
# 2  https://www.bbc.co.uk/news/business-60623941?a...
# 3  https://www.bbc.co.uk/news/uk-60579079?at_medi...
# 4  https://www.bbc.co.uk/news/business-60642786?a...
#
#                                          description
# 0  The Ukrainian president says the country will ...
# 1  Jeremy Bowen was on the frontline in Irpin, as...
# 2  One of the world's biggest fertiliser firms sa...
# 3  The parents of the Manchester Arena bombing's ...
# 4  Consumers are feeling the impact of higher ene...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42115 entries, 0 to 42114
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   title        42115 non-null  object
#  1   pubDate      42115 non-null  object
#  2   guid         42115 non-null  object
#  3   link         42115 non-null  object
#  4   description  42115 non-null  object
# dtypes: object(5)
# memory usage: 1.6+ MB

# %%
df.isnull().sum()
# Out:
# title          0
# pubDate        0
# guid           0
# link           0
# description    0
# dtype: int64

# %%
df.describe()
# Out:
#                                                     title  \
# count                                               42115
# unique                                              39653
# top     Election poll tracker: How do the parties comp...
# freq                                                   34
#
#                               pubDate  \
# count                           42115
# unique                          40189
# top     Tue, 20 Aug 2024 11:35:33 GMT
# freq                               14
#
#                                                 guid  \
# count                                          42115
# unique                                         39203
# top     https://www.bbc.co.uk/news/business-61634959
# freq                                              63
#
#                                                      link  \
# count                                               42115
# unique                                              37856
# top     https://www.bbc.co.uk/news/business-61634959?a...
# freq                                                   61
#
#                                               description
# count                                               42115
# unique                                              38731
# top     How closely have you been paying attention to ...
# freq                                                   80

# %%
#-----------------text cleaning-------------------------

# %%
def clean_text(text):
    text=text.lower()
    text=re.sub(r"[^a-zA-Z# ]","",text)
    return text

# %%
df['title']=df['title'].apply(clean_text)

# %%
df['description']=df['description'].apply(clean_text)

# %%
df.head()
# Out:
#                                                title  \
# 0  ukraine angry zelensky vows to punish russian ...
# 1  war in ukraine taking cover in a town under at...
# 2           ukraine war catastrophic for global food
# 3  manchester arena bombing saffie roussoss paren...
# 4  ukraine conflict oil price soars to highest le...
#
#                          pubDate  \
# 0  Mon, 07 Mar 2022 08:01:56 GMT
# 1  Sun, 06 Mar 2022 22:49:58 GMT
# 2  Mon, 07 Mar 2022 00:14:42 GMT
# 3  Mon, 07 Mar 2022 00:05:40 GMT
# 4  Mon, 07 Mar 2022 08:15:53 GMT
#
#                                                guid  \
# 0  https://www.bbc.co.uk/news/world-europe-60638042
# 1  https://www.bbc.co.uk/news/world-europe-60641873
# 2      https://www.bbc.co.uk/news/business-60623941
# 3            https://www.bbc.co.uk/news/uk-60579079
# 4      https://www.bbc.co.uk/news/business-60642786
#
#                                                 link  \
# 0  https://www.bbc.co.uk/news/world-europe-606380...
# 1  https://www.bbc.co.uk/news/world-europe-606418...
# 2  https://www.bbc.co.uk/news/business-60623941?a...
# 3  https://www.bbc.co.uk/news/uk-60579079?at_medi...
# 4  https://www.bbc.co.uk/news/business-60642786?a...
#
#                                          description
# 0  the ukrainian president says the country will ...
# 1  jeremy bowen was on the frontline in irpin as ...
# 2  one of the worlds biggest fertiliser firms say...
# 3  the parents of the manchester arena bombings y...
# 4  consumers are feeling the impact of higher ene...

# %%
#---------------stemming-----------------------

# %%
# !pip install gensim
# Out:
# Requirement already satisfied: gensim in c:\users\admin\appdata\local\programs\python\python313\lib\site-packages (4.4.0)
# Requirement already satisfied: numpy>=1.18.5 in c:\users\admin\appdata\local\programs\python\python313\lib\site-packages (from gensim) (2.2.4)
# Requirement already satisfied: scipy>=1.7.0 in c:\users\admin\appdata\local\programs\python\python313\lib\site-packages (from gensim) (1.15.2)
# Requirement already satisfied: smart_open>=1.8.1 in c:\users\admin\appdata\local\programs\python\python313\lib\site-packages (from gensim) (7.6.0)
# Requirement already satisfied: wrapt in c:\users\admin\appdata\local\programs\python\python313\lib\site-packages (from smart_open>=1.8.1->gensim) (2.1.2)
# [notice] A new release of pip is available: 25.1.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from gensim.parsing.preprocessing import STOPWORDS
from nltk.stem import PorterStemmer
from gensim import corpora
from gensim.models import LdaModel

# %%
stemmer=PorterStemmer()

# %%
df['tokens']=df['title'].apply(
    lambda x:[
        stemmer.stem(word)
        for word in x.split()
        if word not in STOPWORDS
    ]
)

# %%
dictionary=corpora.Dictionary(df['tokens'])

# %%
corpus=[dictionary.doc2bow(text) for text in df['tokens']]

# %%
#---------------apply lda------------------------

# %%
lda_model=LdaModel(
    corpus=corpus,
    id2word=dictionary,
    num_topics=3,
    passes=10
)

# %%
for topic in lda_model.print_topics():
    print(topic)

# %%
df['tokens']
