# %%
import pandas as pd
import numpy as np
import random

# %%
df=pd.read_csv('twitter_dataset.csv')

# %%
df.head()
# Out:
#    Tweet_ID        Username  \
# 0         1         julie81
# 1         2   richardhester
# 2         3  williamsjoseph
# 3         4     danielsmary
# 4         5      carlwarren
#
#                                                 Text  Retweets  Likes  \
# 0  Party least receive say or single. Prevent pre...         2     25
# 1  Hotel still Congress may member staff. Media d...        35     29
# 2  Nice be her debate industry that year. Film wh...        51     25
# 3  Laugh explain situation career occur serious. ...        37     18
# 4  Involve sense former often approach government...        27     80
#
#              Timestamp
# 0  2023-01-30 11:00:51
# 1  2023-01-02 22:45:58
# 2  2023-01-18 11:25:19
# 3  2023-04-10 22:06:29
# 4  2023-01-24 07:12:21

# %%
countries=['India','USA','UK','Australia','Sri Lanka']
weights=[0.3,0.2,0.2,0.1,0.2]
df['location']=np.random.choice(countries,size=len(df),p=weights)

# %%
df.head()
# Out:
#    Tweet_ID        Username  \
# 0         1         julie81
# 1         2   richardhester
# 2         3  williamsjoseph
# 3         4     danielsmary
# 4         5      carlwarren
#
#                                                 Text  Retweets  Likes  \
# 0  Party least receive say or single. Prevent pre...         2     25
# 1  Hotel still Congress may member staff. Media d...        35     29
# 2  Nice be her debate industry that year. Film wh...        51     25
# 3  Laugh explain situation career occur serious. ...        37     18
# 4  Involve sense former often approach government...        27     80
#
#              Timestamp   location
# 0  2023-01-30 11:00:51  Sri Lanka
# 1  2023-01-02 22:45:58         UK
# 2  2023-01-18 11:25:19  Australia
# 3  2023-04-10 22:06:29        USA
# 4  2023-01-24 07:12:21  Sri Lanka

# %%
df['location']=df['location'].astype(str).str.strip().str.lower()

# %%
#remove null or empty values
df=df[df['location']!='nan']
df=df[df['location']!='']

# %%
location_counts=df['location'].value_countds()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_30676\2400329006.py in ?()
# ----> 1 location_counts=df['location'].value_countds()
#
# ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'value_countds'
